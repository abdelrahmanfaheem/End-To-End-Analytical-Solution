# %%
 
import pandas as pd
import numpy as np
from sqlalchemy import Boolean, NVARCHAR

from CreateTable.CreateTable import *
from CreateTable.database_connection.connection import get_connection
from ETL.load import send_data
from ETL.extract import *
from ETL.transform import change_column_type ,column_mapping




creat_all_tables()
from sqlalchemy import inspect

inspector = inspect(get_connection("HR_Project"))
print(inspector.get_table_names())


df=read_data(file_path=r"K:\HR Project\Data\HR Data.xlsx",sheet_name="Data")
df.rename(columns=column_mapping(),inplace=True)
send_data(df,column_type=change_column_type (),table_name="employee",database='HR_Project')
# Out:
# Start To get Connection
# All tables created successfully ✅
# Start To get Connection
# ['employee', 'hremployee']
# Start establish Connection
# Start To get Connection
# Engine is open: Engine(mssql+pyodbc://MyUser:***@DESKTOP-HVROBDM\SQLEXPRESS/HR_Project?driver=ODBC+Driver+17+for+SQL+Server)
# Start uploading data...
#  the  Data frame Size is 1470
# Data uploaded successfully!
